# %% [markdown]
# #Ingeset drivers.json file
#
# 1. Read the file using spark dataframe reader API
# 2. Define and enforce schena (preserve the nested structure)
# 3. Add Metadata Columns
#     - Source File
#     - Ingestion Timestamp
# 4. Write to bronze delta table

# %%
dbutils.widgets.text("p_batch_id","")
v_batch_id = dbutils.widgets.get("p_batch_id")

# %%
# %run ../00-Common/01.environment-config

# %%
# %run ../00-Common/02.bronze-helpers

# %%
source_file = f"{landing_folder_path}/{v_batch_id}/drivers.json"
table_name = f"{catalog_name}.{bronze_schema}.drivers"

# %% [markdown]
# ### Step 1 - Read the JSON file using DataFrameReader API

# %%
name_schema = StructType([
    StructField('givenName', StringType()),
    StructField('familyName', StringType())
])

drivers_schema = StructType([
    StructField('driverId', StringType()),
    StructField('name', name_schema),
    StructField('dateOfBirth', DateType()),
    StructField('nationality', StringType()),
    StructField('url', StringType())
])

# %%
drivers_df = (
    spark.read.format('json')
    .schema(drivers_schema)
    .option('mode','FAILFAST')
    .load(source_file)
)

# %%
display(drivers_df)

# %% [markdown]
# ### Step 2 - Add Metadata Columns
# - Source File
# - Ingestion Timestamp

# %%
drivers_final_df = add_ingestion_metadata(drivers_df)

# %%
display(drivers_final_df)

# %% [markdown]
# ### Step 3 - Write to Bronze Delta Table

# %%
write_to_bronze(input_df = drivers_final_df, table_name = table_name, batch_id = v_batch_id)

# %%
display(spark.table(table_name))
