# %% [markdown]
# ## Build Races Dimension
#
# 1. Read silver races table
# 2. Read silver circuits table
# 3. Join the data from races with circuits using circuit_id
# 4. Select the required columns
#     - races.season
#     - races.round
#     - races.race_name
#     - races.race_date
#     - circuits.circuit_name
#     - circuits.locality
#     - circuits.country
# 5. Write the transformed data to gold dim_races

# %%
dbutils.widgets.text("p_batch_id","")
v_batch_id = dbutils.widgets.get("p_batch_id")

# %%
# %run ../00-Common/01.environment-config

# %%
# %run ../00-Common/04.gold-helpers

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
target_table = f"{catalog_name}.{gold_schema}.dim_races"

# %% [markdown]
# ### Step 1 -  Read silver races table

# %%
races_df = spark.table(f"{catalog_name}.{silver_schema}.races").filter((col("batch_id") == v_batch_id))

# %% [markdown]
# ### Step 2 - Read silver circuits table

# %%
circuits_df = spark.table(f"{catalog_name}.{silver_schema}.circuits").filter((col("batch_id") == v_batch_id))

# %% [markdown]
# ### Step 3 - Join the data from races with circuits using circuit_id

# %%
dim_races_df = races_df.join(circuits_df, races_df.circuit_id == circuits_df.circuit_id, "inner")

# %% [markdown]
# ### Step 4 - Select the required columns
# -      races.season
# -      races.round
# -      races.race_name
# -      races.race_date
# -      circuits.circuit_name
# -      circuits.locality
# -      circuits.country

# %%
dim_races_df = dim_races_df.select(
    races_df.season,
    races_df.round,
    races_df.race_name,
    races_df.race_date,
    circuits_df.circuit_name,
    circuits_df.locality,
    circuits_df.country
)

# %% [markdown]
# ### Step 5 - Write the transformed data to gold dim_races

# %%
# (
#     dim_races_df
#     .write
#     .format("delta")
#     .mode("overwrite")
#     .saveAsTable(target_table)
# )

# %%
write_to_gold(
    dim_races_df,
    target_table,
    "t.season = s.season AND t.round = s.round",
    [
        "race_name",
        "race_date",
        "circuit_name",
        "locality",
        "country"
    ]
)

# %%
display(spark.table(target_table))
