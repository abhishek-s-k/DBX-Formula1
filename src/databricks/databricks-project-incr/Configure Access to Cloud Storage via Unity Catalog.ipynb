-- %%
%fs ls 'abfss://demo@databricksprojectextdl.dfs.core.windows.net/'

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_project_ext_dl_demo
URL 'abfss://demo@databricksprojectextdl.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-project-sc`)
COMMENT 'external location for databricks project demo container.';
